# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# df = df.head()
# df = pd.DataFrame(df , columns= ["Species","SepalLengthCm"])
# df.plot (x = "Species",y = "SepalLengthCm",kind = "bar", figsize= (9,8))
# show()

# %%
# plt.xlabel("lenght of sepal column")
# plt.ylabel("sepallenghtcm")
# plt.title("SepalLengthCm")
# plt.plot(x,y,color = 'green',
#         linestyle = 'solid',marker = '*',
#         markerfacecolor = 'red', markersize = 12)
# plt.show()

# %%
df.loc[df["Species"] =="Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
temp = df.loc[df["Species"] == "Iris-setosa"]
sepallengthlist = temp['SepalLengthCm']

# %%
plt.xlabel("Id")
plt.ylabel("SepalLengthCm")
plt.title("setosa")
plt.plot(temp['Id'],temp['SepalLengthCm'],color = 'black',
        linestyle = 'solid',marker = 'o',
        markerfacecolor = 'blue', markersize = 12)
plt.show()
