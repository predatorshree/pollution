# %% [markdown]
# # plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#define data values
x = [1,2,3,4]
y = [2,4,6,8]

# %%
plt.plot(x ,y, linestyle ='dashdot')
plt.show() #display

# %%
x=np.array([1,2,3,4])

# %%
plt.plot(x,x+1, linestyle = 'solid')
plt.plot(x,x+1.5,linestyle = 'dashed')
plt.plot(x ,x+2, linestyle = "dashdot")
plt.xlabel("value of x")
plt.ylabel("value of incremented by .5")
plt.title("line plot")
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
x = []
for i in range(len(df['ph'])):
    x.append(i)
y = df['ph']

# %%
plt.plot(x,y)

# %% [markdown]
# # bar

# %%
import matplotlib.pyplot as plt

# %%
language = ['c','c++','JAVA','PYTHON','R'] #X-AXIS
enrolled =[20,25,36,45,45]

# %%
plt.bar(language,enrolled) #plot the chart
plt.show()

# %% [markdown]
# # water portability 0 1

# %%
portability = df['Potability'].tolist()
x = ['drinkable','undrinkable'] #1 0
y = [0,0]

# %%
for i in range (len(df['Potability'])):
    if(portability[i] == 1):
        y[0] = y[0] + 1
    else:
        y[1] = y[1] + 1

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt

# %%
students = ["om","shree","ram","raj","vinod"]
marks = [50,60,90,80,95]
plt.xlabel("students")
plt.ylabel("marks")
plt.title("students marks")
plt.plot(students,marks,color = 'green',
        linestyle = 'solid',marker = 'o',
        markerfacecolor = 'red', markersize =12)
plt.show()

# %%
#read the iris database
# put it in the dataframe
# extract the iris setosa put it in the second data frame
# read the column ceple len and put it in the list 
# generate a sequence of numbers upto ceple len cl 
plot the line  plot with line color green line style solid and makersize is 12
# (students,marks,color = 'green',
#         linestyle = 'solid',marker = 'star',
#         markerfacecolor = 'red', markersize =12)
